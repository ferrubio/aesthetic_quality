# %%
import numpy as np

# %%
np.arange(-8.5,9.5)
# Out:
# array([-8.5, -7.5, -6.5, -5.5, -4.5, -3.5, -2.5, -1.5, -0.5,  0.5,  1.5,
#         2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5])

# %%
print("hola")
# Out:
# hola

# %%
from skimage import feature
from skimage import io
from skimage import color
import skimage

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
moon = io.imread('/home/frubio/sowwy.jpg',as_grey=True)
#moon = color.rgb2gray(moon)

# %%
plt.imshow(moon,cmap='gray')

# %%
new_moon = skimage.filters.gaussian(moon,sigma=1)

# %%
plt.imshow(new_moon,cmap='gray')

# %%
new_moon
# Out:
# array([[ 0.27470104,  0.27470104,  0.27470104, ...,  0.81793647,
#          0.81793647,  0.81793647],
#        [ 0.27491277,  0.27491277,  0.27491277, ...,  0.82429915,
#          0.82429915,  0.82429915],
#        [ 0.2758622 ,  0.2758622 ,  0.2758622 , ...,  0.82913211,
#          0.82913211,  0.82913211],
#        ...,
#        [ 0.74731158,  0.74587694,  0.74569067, ...,  0.74449364,
#          0.74353698,  0.74193887],
#        [ 0.74573659,  0.74450493,  0.74326449, ...,  0.74069748,
#          0.73939962,  0.73724837],
#        [ 0.74316692,  0.74176393,  0.74044674, ...,  0.73595076,
#          0.73457146,  0.73229662]])

# %%
moon = io.imread('/home/frubio/sowwy.jpg')

# %%
moon[:,:,0]
# Out:
# array([[ 51,  51,  51, ..., 210, 210, 210],
#        [ 51,  51,  51, ..., 213, 213, 213],
#        [ 51,  51,  51, ..., 215, 215, 215],
#        ...,
#        [239, 239, 238, ..., 241, 240, 239],
#        [238, 238, 237, ..., 239, 238, 237],
#        [237, 236, 236, ..., 237, 236, 235]], dtype=uint8)
